# %% [markdown]
# # COGS 108 - Data Checkpoint

# %% [markdown]
# Team list and credits:
# - Tom Rufino: Background research, project administration, writing – original draft (created shared doc for group to add for proposal sections)
# - Summer Lenhart:  Background research, writing – original draft
# - Dylan Le: Data curation, software, writing – original draft
# - Dylan Han: Background research, writing – original draft

# %% [markdown]
# ## Research Question

# %% [markdown]
# __What attributes in San Diegan restaurants are associated with higher reviews on Yelp?__

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# San Diego is a growing hub for food, with recent data estimating approximately 5,000 restaurants across the county.<a name="cite_ref-1"></a>[<sup>1</sup>](#cite_note-1) Highly regarded for its quality Mexican cuisine, San Diego also hosts a variety of different restaurants with popular spots for Asian food, seafood, fusion, fast food, coffee, and desserts. But amidst the vast array of options available, what sets apart a local favorite from a hard “maybe”? Is it outdoor seating to take in the unique climate? Takeout options to expedite food pickups during rush hour? Or pure ambiance to draw in curious passerbys?
#
# In this project we aim to analyze Yelp data from restaurants in San Diego to identify key features that contribute to a restaurant’s success. We hope our results will provide a better understanding of the San Diego restaurant-goer demographic, from tourists to locals, so that businesses can understand the best way to cater to and enhance the dining experience for their patrons.
#
# To begin our search for background data we explored a past project with a broader scope of restaurants in the US. It identified differences in rating distributions based on cuisine type, with statistical tests rejecting the possibility of these differences occurring by chance.<a name="cite_ref-2"></a>[<sup>2</sup>](#cite_note-2) In the context of our project, this motivated us to pursue cuisines as a possible attribute for a restaurant’s success here in San Diego. Analyzing associations between cuisine type and rating may give insight into which types of cuisines tend to perform well. Looking at San Diego's population census with 29.6% Hispanic and 17.2% Asian being the highest non-white ethnicities, we predict these cuisines will be associated with high ratings.<a name="cite_ref-3"></a>[<sup>3</sup>](#cite_note-3) San Diego has notable Vietnamese and Filipino populations, so we will focus on these types of cuisine.
#
# Restaurant attributes such as service quality, price, and atmosphere are broadly applicable across restaurant types and are particularly relevant to online review platforms such as Yelp. Prior research, including Chun (2020), has examined how key restaurant attributes such as food quality, service quality, price, and atmosphere influence customer satisfaction in Mongolia. Using survey-based data and statistical analysis, Chun (2020) found that food quality and service quality exhibit the strongest positive correlations with customer satisfaction.<a name="cite_ref-4"></a>[<sup>4</sup>](#cite_note-4)
#
# There has been prior research on what attributes on Yelp can contribute to a restaurant’s success. Studies using data from Yelp have found that data is not random and there are common denominators for success. One example found that across the US, restaurants have significant differences in cuisines which show that certain cuisines perform dramatically better than others because of customer’s preferences. Additionally, factors such as delivery options, reservations, and group accommodations were associated with higher star ratings on Yelp. These observations could potentially be found in the San Diego market as well.
#
# Food quality was identified as the strongest predictor of satisfaction, even when controlling for other factors such as price and atmosphere. In the context of this project, food quality can be approximated using information extracted from Yelp review text, including sentiment, tone, and the presence of positive or negative words and phrases. Service quality, defined in the study as staff friendliness and speed of service, also demonstrated a strong positive relationship with customer satisfaction. On Yelp, service quality may be indirectly measured through business attributes such as Good for Groups, Reservations, and Delivery.<a name="cite_ref-5"></a>[<sup>5</sup>](#cite_note-5)
#
# The weakest, though still positive, correlation observed in the study was associated with the atmosphere and the physical dining environment. Chun (2020) suggests this may be due to variation across restaurant types, such as dine-in versus takeout establishments. Yelp attributes related to atmosphere, including Outdoor Seating, Noise Level, Has TV, and Ambience, can therefore be analyzed in this project to assess whether similar patterns are observed among restaurants in San Diego.
#
# 1. <a name="cite_note-1"></a> [^](#cite_ref-1) How Many Restaurants Are in San Diego? (2026). *Foodylytics*. https://www.foodylytics.com/statistics/california/san-diego.
# 2. <a name="cite_note-2"></a> [^](#cite_ref-2) San Diego, CA | Data USA (2023). *DATAUSA*. https://datausa.io/profile/geo/san-diego-ca.
# 3. <a name="cite_note-3"></a> [^](#cite_ref-3) Wen Ma et al. (2020). COGS 108 - Final Project. https://github.com/COGS108/FinalProjects-Wi20/blob/master/FinalProject_group071.ipynb.
# 4. <a name="cite_note-4"></a> [^](#cite_ref-4) Chun, Se-Hak, and Ariunzaya Nyam-Ochir (Sept 2020). The Effects of Fast Food Restaurant Attributes on Customer Satisfaction, Revisit Intention, and Recommendation Using DINESERV Scale. *Sustainability*, *12*(18), 7435–35. https://doi.org/10.3390/su12187435.
# 5. <a name="cite_note-5"></a> [^](#cite_ref-5) Emitis Alikhani, Hassan F. Gholipour, Hossein Abbasinejad, and Ramtin Rafat Nezhad (May 2025). Review content and customer satisfaction: a textual analysis of Yelp restaurant reviews, 7435–35. https://www.sciencedirect.com/org/science/article/pii/S0007070X25000710

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# We predict that restaurants in San Diego with attributes such as wifi access, longer operating hours, lower average prices, outdoor seating, ample parking, high ambience, reservations, good for groups, and takeout options will be correlated with higher Yelp ratings. We predict that Mexican, Vietnamese, and Filipino cuisines will have higher rating distributions.

# %% [markdown]
# ## Data

# %% [markdown]
# ### Yelp's Open Dataset
#
# The dataset contains information on restaurant-related businesses located in Santa Barbara, California. Each row represents a single restaurant and includes location identifiers such as city, address, state, and postal_code. The stars variable represents the average Yelp rating on a scale of 1–5, with higher values indicating positive reviews. review_count measures the total number of Yelp reviews submitted for that particular establishment, which can serve as a proxy for popularity, longevity, or customer engagement. The is_open variable is a Boolean indicator that denotes whether the establishment is still in operation.
#
# The categories and categories_list fields provide the type of cuisine or business classification is associated with a particular restaurant. Many establishments fall under multiple categories, so the dataset has multi-label classification or grouping by cuisine. Variables with the prefix attr_ provide additional details about the service and amenities offered. attr_RestaurantsReservations indicates whether reservations are accepted or not, attr_RestaurantsDelivery tells if they offer a delivery service, and attr_RestaurantsTableService indicates whether full table service is provided. In addition, variables used to describe the accessibility and environment of the restaurant include: attr_WheelchairAccessible, attr_GoodForKids, and attr_RestaurantsGoodForGroups. attr_WiFi indicates if WiFi is available (e.g., free or no), and attr_Ambience contains nested descriptors such as romantic, casual, hipster, or touristy, which characterize the restaurant’s atmosphere. Operating hours are recorded for each day of the week (e.g., hours_Saturday) and are formatted as time ranges in 24-hour notation.
#
# In working with this dataset, it should be noted that Yelp ratings are subjective and reflect opinions rather than objective measures of quality. Businesses that have higher review counts may have average ratings that are more stable, whereas those with fewer reviews may have more variability. The data may be subject to self-selection bias, as people who post reviews are not necessarily representative of the broader population.

# %%
# Run this code every time when you're actively developing modules in .py files.  It's not needed if you aren't making modules
#
## this code is necessary for making sure that any modules we load are updated here 
## when their source code .py files are modified

# %load_ext autoreload
# %autoreload 2

# %%
# Setup code -- this only needs to be run once after cloning the repo!
# this code downloads the data from its source to the `data/00-raw/` directory
# if the data hasn't updated you don't need to do this again!

# if you don't already have these packages (you should!) uncomment this line
# %pip install requests tqdm

import sys
sys.path.append('./modules') # this tells python where to look for modules to import

import get_data # this is where we get the function we need to download data

# replace the urls and filenames in this list with your actual datafiles
# yes you can use Google drive share links or whatever
# format is a list of dictionaries; 
# each dict has keys of 
#   'url' where the resource is located
#   'filename' for the local filename where it will be stored 
datafiles = [
    { 'url': 'https://raw.githubusercontent.com/fivethirtyeight/data/refs/heads/master/airline-safety/airline-safety.csv', 'filename':'airline-safety.csv'},
    { 'url': 'https://raw.githubusercontent.com/fivethirtyeight/data/refs/heads/master/bad-drivers/bad-drivers.csv', 'filename':'bad-drivers.csv'}
]

get_data.get_raw(datafiles,destination_directory='data/00-raw/')

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


def load_data(path):
    """Load Yelp business JSON (JSON Lines format)."""
    return pd.read_json(path, lines=True)


def filter_restaurants(df):
    """Keep only rows where categories contain 'Restaurants'."""
    df = df.copy()
    df["categories"] = df["categories"].fillna("")
    return df[df["categories"].str.contains("Restaurants", case=False, na=False)].copy()


def flatten_column(df, column, prefix):
    """Flatten nested dict columns like attributes or hours."""
    if column not in df.columns:
        return df
    expanded = pd.json_normalize(df[column].fillna({}))
    expanded.columns = [f"{prefix}{col}" for col in expanded.columns]
    df = df.drop(columns=[column]).reset_index(drop=True)
    return pd.concat([df, expanded.reset_index(drop=True)], axis=1)


def clean_types(df):
    """Fix numeric and boolean columns."""
    df = df.copy()

    for col in ["stars", "review_count", "latitude", "longitude"]:
        if col in df.columns:
            df[col] = pd.to_numeric(df[col], errors="coerce")

    if "is_open" in df.columns:
        df["is_open"] = pd.to_numeric(df["is_open"], errors="coerce").map({0: False, 1: True})

    return df


def basic_cleanup(df):
    """Remove duplicates and normalize blanks."""
    df = df.copy()

    if "business_id" in df.columns:
        df = df.drop_duplicates(subset=["business_id"])

    for col in ["name", "address", "city", "state", "postal_code"]:
        if col in df.columns:
            df[col] = df[col].replace("", np.nan)

    return df


def quick_visuals(df):
    """Simple sanity-check plots."""
    if "stars" in df.columns:
        plt.figure()
        df["stars"].dropna().plot(kind="hist", bins=20)
        plt.title("Restaurant Star Distribution")
        plt.xlabel("Stars")
        plt.show()

    if "review_count" in df.columns:
        plt.figure()
        np.log1p(df["review_count"].dropna()).plot(kind="hist", bins=30)
        plt.title("log(1 + Review Count)")
        plt.xlabel("log1p(review_count)")
        plt.show()

# %%
def flatten_dict_column(df, col, prefix):
    if col not in df.columns:
        return df

    series = df[col].apply(lambda x: {} if pd.isna(x) else x)
    expanded = pd.json_normalize(series)
    expanded.columns = [f"{prefix}{c}" for c in expanded.columns]
    df = df.drop(columns=[col]).reset_index(drop=True)
    df = pd.concat([df, expanded], axis=1)

    return df

# %%
BUSINESS_JSON = "data/00-raw/raw_yelp_academic_dataset_business.json"
OUT_CSV = "data/02-processed/restaurants_clean.csv"

# Load
df = load_data(BUSINESS_JSON)

# Filter
restaurants = filter_restaurants(df)

# Flatten nested columns
restaurants = flatten_column(restaurants, "attributes", "attr_")
restaurants = flatten_column(restaurants, "hours", "hours_")

# Clean types
restaurants = clean_types(restaurants)

# Basic cleanup
restaurants = basic_cleanup(restaurants)

print("Total rows:", len(df))
print("Restaurant rows:", len(restaurants))
print(restaurants[["stars", "review_count"]].describe())

# Visualize
quick_visuals(restaurants)

# Save
restaurants.to_csv(OUT_CSV, index=False)
print("Saved to:", OUT_CSV)

# %%
# create yelp_df dataset from processed Yelp data
yelp_df = pd.read_csv('processed_yelp_academic_dateset_business.csv', low_memory=False).reset_index()
yelp_df.head()
# Out:
#    index             business_id                   name              address  \
# 0      0  MTSW4McQd7CbVtyjqoe9mw     St Honore Pastries          935 Race St
# 1      1  CF33F8-E6oudUQ46HnavjQ         Sonic Drive-In        615 S Main St
# 2      2  k0hlBqXX-Bt0vf1op7Jr1w  Tsevi's Pub And Grill    8025 Mackenzie Rd
# 3      3  bBDDEgkFA1Otx9Lfe7BZUQ         Sonic Drive-In  2312 Dickerson Pike
# 4      4  eEOYSgkmpB90uNA7lDOMRA  Vietnamese Food Truck                  NaN
#
#            city state postal_code   latitude  longitude  stars  ...  \
# 0  Philadelphia    PA       19107  39.955505 -75.155564    4.0  ...
# 1  Ashland City    TN       37015  36.269593 -87.058943    2.0  ...
# 2        Affton    MO       63123  38.565165 -90.321087    3.0  ...
# 3     Nashville    TN       37207  36.208102 -86.768170    1.5  ...
# 4     Tampa Bay    FL       33602  27.955269 -82.456320    4.0  ...
#
#    attr_DietaryRestrictions  attr_HairSpecializesIn attr_AcceptsInsurance  \
# 0                       NaN                     NaN                   NaN
# 1                       NaN                     NaN                   NaN
# 2                       NaN                     NaN                   NaN
# 3                       NaN                     NaN                   NaN
# 4                       NaN                     NaN                   NaN
#
#   hours_Monday hours_Tuesday hours_Wednesday hours_Thursday hours_Friday  \
# 0     7:0-20:0      7:0-20:0        7:0-20:0       7:0-20:0     7:0-21:0
# 1      0:0-0:0      6:0-22:0        6:0-22:0       6:0-22:0      9:0-0:0
# 2          NaN           NaN             NaN            NaN          NaN
# 3      0:0-0:0      6:0-21:0        6:0-21:0       6:0-16:0     6:0-16:0
# 4    11:0-14:0     11:0-14:0       11:0-14:0      11:0-14:0    11:0-14:0
#
#   hours_Saturday  hours_Sunday
# 0       7:0-21:0      7:0-21:0
# 1       9:0-22:0      8:0-22:0
# 2            NaN           NaN
# 3       6:0-17:0      6:0-21:0
# 4       5:0-10:0     15:0-18:0
#
# [5 rows x 60 columns]

# %%
ca_df = yelp_df[yelp_df['state'] == 'CA']
ca_df['city'].unique() # most of our CA restaurant data is in Santa Barbara
# Out:
# array(['Santa Barbara', 'Isla Vista', 'Goleta', 'Carpinteria',
#        'Montecito', 'Summerland', 'Santa  Barbara', 'Truckee'],
#       dtype=object)

# %%
sb_count = (
    (ca_df['city'] == 'Santa Barbara').sum() + 
    (ca_df['city'] == 'Isla Vista').sum() +
    (ca_df['city'] == 'Goleta').sum() +
    (ca_df['city'] == 'Carpinteria').sum() + 
    (ca_df['city'] == 'Montecito').sum() + 
    (ca_df['city'] == 'Summerland').sum() +
    (ca_df['city'] == 'Santa  Barbara').sum())

sb_count # 1,160 restaurants in Santa Barbara area
# Out:
# 1160

# %%
# create sb_df by filtering yelp_df to only restaurants in Santa Barbara area
sb_list = ['Santa Barbara', 'Isla Vista', 'Goleta', 'Carpinteria', 'Montecito', 'Summerland', 'Santa  Barbara']
sb_df = ca_df[ca_df['city'].isin(sb_list)]
sb_df
# Out:
#        index             business_id                             name  \
# 37        37  IDtLPgUrqorrpqSLdfMhZQ             Helena Avenue Bakery
# 55        55  SZU9c8V2GuREDN5KgyHFJw  Santa Barbara Shellfish Company
# 146      146  4xhGQGdGqU60BIznBjqnuA     California Tacos and Taproom
# 154      154  ifjluUv4VASwmFqEp8cWlQ                    Marty's Pizza
# 166      166  VeFfrEZ4iWaecrQg6Eq4cg                         Cal Taco
# ...      ...                     ...                              ...
# 52204  52204  izSgTrqebu8bN8ONOCs6cQ                       Oat Bakery
# 52223  52223  2xxkaRy7rP5EUyjFt2J5kA                      Nikka Ramen
# 52235  52235  TSwMwVq5GtQh5LW2t32uGA      Woody's Roundup Bar & Grill
# 52245  52245  8BUr8GviR2o_b-brO21wwQ                Kyle's Isla Vista
# 52253  52253  uriD7RFuHhLJeDdKaf0nFA                       Pizza Guru
#
#                                         address           city state  \
# 37                        131 Anacapa St, Ste C  Santa Barbara    CA
# 55                            230 Stearns Wharf  Santa Barbara    CA
# 146                   956 Embarcadero Del Norte     Isla Vista    CA
# 154                          2733 De La Vina St  Santa Barbara    CA
# 166                   7320 Hollister Ave, Ste 1         Goleta    CA
# ...                                         ...            ...   ...
# 52204                              5 W Haley St  Santa Barbara    CA
# 52223                           5701 Calle Real         Goleta    CA
# 52235  Earl Warren Showgrounds, 3400 Calle Real  Santa Barbara    CA
# 52245                   900 Embarcadero Del Mar     Isla Vista    CA
# 52253                             3534 State St  Santa Barbara    CA
#
#       postal_code   latitude   longitude  stars  ...  \
# 37          93101  34.414445 -119.690672    4.0  ...
# 55          93101  34.408715 -119.685019    4.0  ...
# 146         93117  34.411555 -119.855077    4.0  ...
# 154         93105  34.436236 -119.726147    4.0  ...
# 166         93117  34.430542 -119.882367    4.0  ...
# ...           ...        ...         ...    ...  ...
# 52204       93101  34.416548 -119.695626    5.0  ...
# 52223       93117  34.440885 -119.823523    4.5  ...
# 52235       93105  34.430895 -119.735645    2.0  ...
# 52245       93117  34.412966 -119.856886    2.5  ...
# 52253       93105  34.440689 -119.739681    4.0  ...
#
#        attr_DietaryRestrictions  attr_HairSpecializesIn attr_AcceptsInsurance  \
# 37                          NaN                     NaN                   NaN
# 55                          NaN                     NaN                   NaN
# 146                         NaN                     NaN                   NaN
# 154                         NaN                     NaN                   NaN
# 166                         NaN                     NaN                   NaN
# ...                         ...                     ...                   ...
# 52204                       NaN                     NaN                   NaN
# 52223                       NaN                     NaN                   NaN
# 52235                       NaN                     NaN                   NaN
# 52245                       NaN                     NaN                   NaN
# 52253                       NaN                     NaN                   NaN
#
#       hours_Monday hours_Tuesday hours_Wednesday hours_Thursday hours_Friday  \
# 37         0:0-0:0      8:0-14:0        8:0-14:0       8:0-14:0     8:0-14:0
# 55         0:0-0:0     11:0-21:0       11:0-21:0      11:0-14:0    11:0-21:0
# 146        0:0-0:0     10:0-22:0       10:0-22:0      10:0-22:0    10:0-22:0
# 154            NaN    11:0-21:30      11:0-21:30     11:0-21:30   11:0-21:30
# 166        0:0-0:0     8:0-20:30       8:0-20:30      8:0-20:30    8:0-20:30
# ...            ...           ...             ...            ...          ...
# 52204      0:0-0:0      9:0-18:0       9:0-14:30      9:0-14:30    9:0-14:30
# 52223          NaN    17:0-21:30      17:0-21:30     17:0-21:30   17:0-21:30
# 52235          NaN           NaN             NaN            NaN          NaN
# 52245          NaN           NaN             NaN            NaN          NaN
# 52253    15:0-21:0     15:0-21:0       15:0-21:0      15:0-21:0    15:0-21:0
#
#       hours_Saturday  hours_Sunday
# 37          8:0-14:0      8:0-14:0
# 55         11:0-21:0     11:0-21:0
# 146        12:0-22:0    12:0-20:30
# 154       11:0-21:30    11:0-21:30
# 166        8:0-20:30     8:0-20:30
# ...              ...           ...
# 52204      9:0-14:30           NaN
# 52223     17:0-21:30    17:0-21:30
# 52235            NaN           NaN
# 52245            NaN           NaN
# 52253      15:0-21:0     15:0-21:0
#
# [1160 rows x 60 columns]

# %%
sb_df.columns # let's look at the different attributes available to us
# Out:
# Index(['index', 'business_id', 'name', 'address', 'city', 'state',
#        'postal_code', 'latitude', 'longitude', 'stars', 'review_count',
#        'is_open', 'categories', 'categories_list', 'attr_RestaurantsDelivery',
#        'attr_OutdoorSeating', 'attr_BusinessAcceptsCreditCards',
#        'attr_BusinessParking', 'attr_BikeParking',
#        'attr_RestaurantsPriceRange2', 'attr_RestaurantsTakeOut',
#        'attr_ByAppointmentOnly', 'attr_WiFi', 'attr_Alcohol', 'attr_Caters',
#        'attr_RestaurantsAttire', 'attr_RestaurantsReservations',
#        'attr_Ambience', 'attr_GoodForKids', 'attr_CoatCheck',
#        'attr_DogsAllowed', 'attr_RestaurantsTableService',
#        'attr_RestaurantsGoodForGroups', 'attr_WheelchairAccessible',
#        'attr_HasTV', 'attr_HappyHour', 'attr_DriveThru', 'attr_NoiseLevel',
#        'attr_GoodForMeal', 'attr_BusinessAcceptsBitcoin', 'attr_Smoking',
#        'attr_Music', 'attr_GoodForDancing', 'attr_BestNights', 'attr_BYOB',
#        'attr_Corkage', 'attr_BYOBCorkage', 'attr_RestaurantsCounterService',
#        'attr_Open24Hours', 'attr_AgesAllowed', 'attr_DietaryRestrictions',
#        'attr_HairSpecializesIn', 'attr_AcceptsInsurance', 'hours_Monday',
#        'hours_Tuesday', 'hours_Wednesday', 'hours_Thursday', 'hours_Friday',
#        'hours_Saturday', 'hours_Sunday'],
#       dtype='object')

# %%
sb_df.head()
# Out:
#      index             business_id                             name  \
# 37      37  IDtLPgUrqorrpqSLdfMhZQ             Helena Avenue Bakery
# 55      55  SZU9c8V2GuREDN5KgyHFJw  Santa Barbara Shellfish Company
# 146    146  4xhGQGdGqU60BIznBjqnuA     California Tacos and Taproom
# 154    154  ifjluUv4VASwmFqEp8cWlQ                    Marty's Pizza
# 166    166  VeFfrEZ4iWaecrQg6Eq4cg                         Cal Taco
#
#                        address           city state postal_code   latitude  \
# 37       131 Anacapa St, Ste C  Santa Barbara    CA       93101  34.414445
# 55           230 Stearns Wharf  Santa Barbara    CA       93101  34.408715
# 146  956 Embarcadero Del Norte     Isla Vista    CA       93117  34.411555
# 154         2733 De La Vina St  Santa Barbara    CA       93105  34.436236
# 166  7320 Hollister Ave, Ste 1         Goleta    CA       93117  34.430542
#
#       longitude  stars  ...  attr_DietaryRestrictions  attr_HairSpecializesIn  \
# 37  -119.690672    4.0  ...                       NaN                     NaN
# 55  -119.685019    4.0  ...                       NaN                     NaN
# 146 -119.855077    4.0  ...                       NaN                     NaN
# 154 -119.726147    4.0  ...                       NaN                     NaN
# 166 -119.882367    4.0  ...                       NaN                     NaN
#
#     attr_AcceptsInsurance hours_Monday hours_Tuesday hours_Wednesday  \
# 37                    NaN      0:0-0:0      8:0-14:0        8:0-14:0
# 55                    NaN      0:0-0:0     11:0-21:0       11:0-21:0
# 146                   NaN      0:0-0:0     10:0-22:0       10:0-22:0
# 154                   NaN          NaN    11:0-21:30      11:0-21:30
# 166                   NaN      0:0-0:0     8:0-20:30       8:0-20:30
#
#     hours_Thursday hours_Friday hours_Saturday  hours_Sunday
# 37        8:0-14:0     8:0-14:0       8:0-14:0      8:0-14:0
# 55       11:0-14:0    11:0-21:0      11:0-21:0     11:0-21:0
# 146      10:0-22:0    10:0-22:0      12:0-22:0    12:0-20:30
# 154     11:0-21:30   11:0-21:30     11:0-21:30    11:0-21:30
# 166      8:0-20:30    8:0-20:30      8:0-20:30     8:0-20:30
#
# [5 rows x 60 columns]

# %% [markdown]
# Some of these columns contain only NaN values. Let's get rid of them, and get rid of some other columns we won't be looking at.

# %%
sb_clean = sb_df.dropna(axis=1, how='all')
sb_clean = sb_clean[[
    "address",
    "city",
    "state",
    "postal_code",
    "stars",
    "review_count",
    "is_open",
    "categories",
    "categories_list",
    "attr_RestaurantsDelivery",
    "attr_OutdoorSeating",
    "attr_BusinessAcceptsCreditCards",
    "attr_RestaurantsPriceRange2",
    "attr_RestaurantsTakeOut",
    "attr_WiFi",
    "attr_RestaurantsReservations",
    "attr_Ambience",
    "attr_GoodForKids",
    "attr_DogsAllowed",
    "attr_RestaurantsTableService",
    "attr_RestaurantsGoodForGroups",
    "attr_WheelchairAccessible",
    "attr_Open24Hours",
    "hours_Saturday",
]]
sb_df = sb_clean
sb_df.columns
# Out:
# Index(['address', 'city', 'state', 'postal_code', 'stars', 'review_count',
#        'is_open', 'categories', 'categories_list', 'attr_RestaurantsDelivery',
#        'attr_OutdoorSeating', 'attr_BusinessAcceptsCreditCards',
#        'attr_RestaurantsPriceRange2', 'attr_RestaurantsTakeOut', 'attr_WiFi',
#        'attr_RestaurantsReservations', 'attr_Ambience', 'attr_GoodForKids',
#        'attr_DogsAllowed', 'attr_RestaurantsTableService',
#        'attr_RestaurantsGoodForGroups', 'attr_WheelchairAccessible',
#        'attr_Open24Hours', 'hours_Saturday'],
#       dtype='object')

# %%
sb_df.head()
# Out:
#                        address           city state postal_code  stars  \
# 37       131 Anacapa St, Ste C  Santa Barbara    CA       93101    4.0
# 55           230 Stearns Wharf  Santa Barbara    CA       93101    4.0
# 146  956 Embarcadero Del Norte     Isla Vista    CA       93117    4.0
# 154         2733 De La Vina St  Santa Barbara    CA       93105    4.0
# 166  7320 Hollister Ave, Ste 1         Goleta    CA       93117    4.0
#
#      review_count  is_open                                         categories  \
# 37            389     True  Food, Restaurants, Salad, Coffee & Tea, Breakf...
# 55           2404     True  Live/Raw Food, Restaurants, Seafood, Beer Bar,...
# 146            49    False  Mexican, Beer Bar, Bars, Sports Bars, Nightlif...
# 154            64     True                                 Pizza, Restaurants
# 166           189     True  Burgers, Cafes, Restaurants, Mexican, American...
#
#                                        categories_list  \
# 37   ['Food', 'Restaurants', 'Salad', 'Coffee & Tea...
# 55   ['Live/Raw Food', 'Restaurants', 'Seafood', 'B...
# 146  ['Mexican', 'Beer Bar', 'Bars', 'Sports Bars',...
# 154                           ['Pizza', 'Restaurants']
# 166  ['Burgers', 'Cafes', 'Restaurants', 'Mexican',...
#
#     attr_RestaurantsDelivery  ... attr_WiFi attr_RestaurantsReservations  \
# 37                       NaN  ...     u'no'                        False
# 55                      True  ...     u'no'                        False
# 146                     True  ...   u'free'                        False
# 154                     True  ...       NaN                        False
# 166                     True  ...     u'no'                         True
#
#                                          attr_Ambience attr_GoodForKids  \
# 37   {'touristy': False, 'hipster': True, 'romantic...             True
# 55   {'touristy': False, 'hipster': False, 'romanti...             True
# 146  {'touristy': False, 'hipster': False, 'romanti...              NaN
# 154  {'touristy': None, 'hipster': False, 'romantic...             True
# 166  {u'divey': False, u'hipster': False, u'casual'...             True
#
#     attr_DogsAllowed attr_RestaurantsTableService  \
# 37              True                        False
# 55               NaN                          NaN
# 146              NaN                          NaN
# 154              NaN                          NaN
# 166             True                         True
#
#     attr_RestaurantsGoodForGroups attr_WheelchairAccessible attr_Open24Hours  \
# 37                           True                      True              NaN
# 55                          False                       NaN              NaN
# 146                           NaN                      True              NaN
# 154                          True                       NaN              NaN
# 166                          True                      True              NaN
#
#     hours_Saturday
# 37        8:0-14:0
# 55       11:0-21:0
# 146      12:0-22:0
# 154     11:0-21:30
# 166      8:0-20:30
#
# [5 rows x 24 columns]

# %% [markdown]
# We're going to create a test plot comparing price ranges (1-4) and star ratings.

# %%
plt.figure(figsize=(7,4))
sns.boxplot(
    data=sb_df.dropna(subset=["attr_RestaurantsPriceRange2"]),
    x="attr_RestaurantsPriceRange2",
    y="stars"
)
plt.title("Yelp Stars by Price Range (Santa Barbara Restaurants)")
plt.xlabel("Price range (RestaurantsPriceRange2)")
plt.ylabel("Stars")
plt.show()

# %% [markdown]
# ## Ethics
#
# Instructions: Keep the contents of this cell. For each item on the checklist
# -  put an X there if you've considered the item
# -  IF THE ITEM IS RELEVANT place a short paragraph after the checklist item discussing the issue.
#
# Items on this checklist are meant to provoke discussion among good-faith actors who take their ethical responsibilities seriously. Your teams will document these discussions and decisions for posterity using this section.  You don't have to solve these problems, you just have to acknowledge any potential harm no matter how unlikely.
#
# Here is a [list of real world examples](https://deon.drivendata.org/examples/) for each item in the checklist that can refer to.
#
# [![Deon badge](https://img.shields.io/badge/ethics%20checklist-deon-brightgreen.svg?style=popout-square)](http://deon.drivendata.org/)
#
# ### A. Data Collection
#  - [X] **A.1 Informed consent**: If there are human subjects, have they given informed consent, where subjects affirmatively opt-in and have a clear understanding of the data uses to which they consent?
#  - [X] **A.2 Collection bias**: Have we considered sources of bias that could be introduced during data collection and survey design and taken steps to mitigate those?
#
# > Yelp reviews tend to be highly positive or highly negative, could miss out on "eh" experiences. Review bombing and bot reviews are also items to consider as confounds in our data.
#
#  - [X] **A.3 Limit PII exposure**: Have we considered ways to minimize exposure of personally identifiable information (PII) for example through anonymization or not collecting information that isn't relevant for analysis?
#
# > Yelp API does not pull personally identifiable information.
#
#  - [X] **A.4 Downstream bias mitigation**: Have we considered ways to enable testing downstream results for biased outcomes (e.g., collecting data on protected group status like race or gender)?
#
# ### B. Data Storage
#  - [X] **B.1 Data security**: Do we have a plan to protect and secure data (e.g., encryption at rest and in transit, access controls on internal users and third parties, access logs, and up-to-date software)?
#  - [X] **B.2 Right to be forgotten**: Do we have a mechanism through which an individual can request their personal information be removed?
#  - [X] **B.3 Data retention plan**: Is there a schedule or plan to delete the data after it is no longer needed?
#
# ### C. Analysis
#  - [X] **C.1 Missing perspectives**: Have we sought to address blindspots in the analysis through engagement with relevant stakeholders (e.g., checking assumptions and discussing implications with affected communities and subject matter experts)?
#  - [X] **C.2 Dataset bias**: Have we examined the data for possible sources of bias and taken steps to mitigate or address these biases (e.g., stereotype perpetuation, confirmation bias, imbalanced classes, or omitted confounding variables)?
#  - [X] **C.3 Honest representation**: Are our visualizations, summary statistics, and reports designed to honestly represent the underlying data?
#  - [X] **C.4 Privacy in analysis**: Have we ensured that data with PII are not used or displayed unless necessary for the analysis?
#  - [X] **C.5 Auditability**: Is the process of generating the analysis well documented and reproducible if we discover issues in the future?
#
# ### D. Modeling
#  - [X] **D.1 Proxy discrimination**: Have we ensured that the model does not rely on variables or proxies for variables that are unfairly discriminatory?
#  - [X] **D.2 Fairness across groups**: Have we tested model results for fairness with respect to different affected groups (e.g., tested for disparate error rates)?
#  - [X] **D.3 Metric selection**: Have we considered the effects of optimizing for our defined metrics and considered additional metrics?
#
# > Yelp ratings, different attributes create a wide variety of criteria to choose from.
#
#  - [X] **D.4 Explainability**: Can we explain in understandable terms a decision the model made in cases where a justification is needed?
#  - [X] **D.5 Communicate limitations**: Have we communicated the shortcomings, limitations, and biases of the model to relevant stakeholders in ways that can be generally understood?
#
# ### E. Deployment
#  - [X] **E.1 Monitoring and evaluation**: Do we have a clear plan to monitor the model and its impacts after it is deployed (e.g., performance monitoring, regular audit of sample predictions, human review of high-stakes decisions, reviewing downstream impacts of errors or low-confidence decisions, testing for concept drift)?
#  - [X] **E.2 Redress**: Have we discussed with our organization a plan for response if users are harmed by the results (e.g., how does the data science team evaluate these cases and update analysis and models to prevent future harm)?
#  - [X] **E.3 Roll back**: Is there a way to turn off or roll back the model in production if necessary?
#  - [X] **E.4 Unintended use**: Have we taken steps to identify and prevent unintended uses and abuse of the model and do we have a plan to monitor these once the model is deployed?

# %% [markdown]
# ## Team Expectations

# %% [markdown]
# * *Be nice and understanding of everyone's varying experience in datascience.*
# * *Keep all relevant communication to Discord. The more communication the better!*
# * *Decisionmaking: majority vote after hearing out everyone's individual input on the decision.*
# * *Deadlines: if failing to meet a contribution by an expected deadline, notify the group in the Discord ASAP and propose a more realistic deadline.*
# * *Contributions: everyone is encouraged to do a bit of everything. When new tasks present themselves, we will collectively decide who will work on what.*

# %% [markdown]
# ## Project Timeline Proposal

# %% [markdown]
# | Meeting Date  | Meeting Time| Completed Before Meeting  | Discuss at Meeting |
# |---|---|---|---|
# | 2/3  |  5:30 PM | Brainstorm topics/questions  | Finish proposal, decide direction for project |
# | 2/10  |  5:30 PM |  Do background research on topic | Discuss datasets |
# | 2/17  |  5:30 PM | Obtain datasets  | Discuss Wrangling and analytical approaches; finish wrangling for DataCheckpoint   |
# | 3/3  | 5:30 PM  | Begin Analysis | Discuss/edit Analysis; Complete project check-in |
# | 3/10  | 5:30 PM  | Complete analysis; Draft results/conclusion/discussion | Discuss/edit full project |
# | 3/17 | 5:30PM | Prepare script for video | Complete and edit video
