# %% [markdown]
# # Rubric
#
# Instructions: DELETE this cell before you submit via a `git push` to your repo before deadline. This cell is for your reference only and is not needed in your report.
#
# Scoring: Out of 18 points in total.  15 points in the report.  3 points in the video summary of your report for a non-technical audience.
#
# For the report:
# - Each Developing  => -0.5 pts
# - Each Unsatisfactory/Missing => -1 pts
#   - until the score is 0
#
# For the video:
# - Developing  => -1.5 pts
# - Unsatisfactory/Missing => -3 pts
#
# |                                                                                    | Unsatisfactory                                                                                                                                                                                                                                                                                      | Developing                                                                                                                                                                                                                                                                                                                          | Proficient                                                                                                                                                                                                                                                    | Exellent                                                                                                                                                                                                                                                                                                                                                          |
# | ---------------------------------------------------------------------------------- | --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | Title & abstract                                                                   | Title or abstract is confusing or fails to offer important details about the question, variables, context, or methods of the project.                                                                                                                                                               | Title or abstract lacks relevance or fails to offer appropriate details about the question, variables, context, or methods of the project.                                                                                                                                                                                          | Title and abstract are relevant, offering sufficient details about the research project.                                                                                                                                                                      | Title and abstract are informative, succinct, and clear. It offers specific details about the question, variables, context, and proposed methods of the study.                                                                                                                                                                                                    |
# | Background                                                                         | Did not have at least 3 reliable and relevant sources. Or relevant sources were not used in relevant ways                                                                                                                                                                                           | A key component was not connected to the research literature. Selected literature was from unreliable sources. Literary supports were vague or ambiguous.                                                                                                                                                                           | Key research components were connected to relevant, reliable literature.                                                                                                                                                                                      | Narrative integrates critical and logical details from the peer-reviewed or other professional research literature. Each key research component is grounded to the literature. Attention is given to different perspectives, threats to validity, and opinion vs. evidence.                                                                                       |
# | Research question & hypothesis                                                     | Research issue remains unclear. The research purpose, questions, hypotheses, definitions or variables and controls are still largely undefined, or when they are are poorly formed, ambiguous, or not logically connected to the description of the problem. Unclear connections to the literature. | Research issue is identified, but statement is too broad or fails to establish the importance of the problem. The research purpose, questions, hypotheses, definitions or variables and controls are poorly formed, ambiguous, or not logically connected to the description of the problem. Unclear connections to the literature. | Identifies a relevant research issue. Research questions are succinctly stated, connected to the research issue, and supported by the literature. Variables and controls have been identified and described. Connections are established with the literature. | Presents a significant research problem related to the chemical sciences. Articulates clear, reasonable research questions given the purpose, design, and methods of the project. All variables and controls have been appropriately defined. Proposals are clearly supported from the research and theoretical literature. All elements are mutually supportive. |
# | Data description                                                                   | Did not have references to relevant data sources for this problem. Did not describe the data obtained at those sources                                                                                                                                                                              | A key data source was not referenced or described in satisfactory level of detail                                                                                                                                                                                                                                                   | All relevant data sources were referenced and described in terms of their key variables and size                                                                                                                                                              | Multiple data sources for each aspect of the project, All data sources are fully described and referenced. The details of the descriptions also make it clear how they support the needs ot the project.                                                                                                                                                          |
# | Data wrangling                                                                     | Data obviously not tidy and not clean. Or even if they are clean/tidy, there was no demonstration of that fact                                                                                                                                                                                      | Data has some minor problems with tidiness or cleanliness. Potentially these are not problems but it wasn't fully demonstrated to be the case in the code                                                                                                                                                                           | Data are made tidy and clean, or are clearly demonstrated to be so from download                                                                                                                                                                              | Data wrangling is complete, but also particularly thoroughly done for a very tough case. Often free text parsing is a bear like this, and doing it well can mean a million edge cases.                                                                                                                                                                            |
# | Data visualizations                                                                | Many plots don't capture useful information, or their display of information is difficult to understand.. Legends, labels, axes, titles, captions, etc of many plots may be poor or missing. Figures are not referenced in the main text.                                                           | Most plots make sense and capture useful information. Legends, labels, axes, titles, captions, etc are mostly legible and adequately describe the content of the figure. Most figures are referenced or explained inside the main text and not just left hanging.                                                                   | Plots make sense and capture useful information. Legends, labels, axes, titles, captions, etc are clearly legible and adequately describe the content of the figure. Figures are referenced or explained inside the main text and not just left hanging.      | Plots are beautiful and information dense. Legends, labels, axes, titles, captions, etc clearly describe the content of the figure. Figures are well integrated with the text.                                                                                                                                                                                    |
# | Data analysis and results                                                          | Lacks any metrics or at least metrics that are relevant to the problem                                                                                                                                                                                                                              | Some metrics selected are not appropriate for the problem or the metrics selected are not described sufficiently                                                                                                                                                                                                                    | All metrics described are appropriate and and described sufficiently                                                                                                                                                                                          | The metrics are described clearly and succinctly. Their appropriateness for addressing the research problem is clearly described.                                                                                                                                                                                                                                 |
# | Ethics                                                                             | Only tries a baseline model, never advances to proper model/hyper-parameter selection                                                                                                                                                                                                               | Only investigates one minimal aspect of their problem, e.g. just did a single hyperparameter selection on a single model                                                                                                                                                                                                            | Does a good model/hyper-parameter selection. Only attempts minimal secondary analysis                                                                                                                                                                         | Does a good model/hyper-parameter selection. Performs multiple secondary analysis such as learning curves, heat maps looking at where in the parameter space things are good/bad, uses statistical testing                                                                                                                                                        |
# | Conclusion and discussion                                                          | Doesn't have a narrative/conclusions of what the report accomplished. Or very minimal conclusions, like "X was best" without anything else                                                                                                                                                          | Has narrative/conclusions, but it feels perfunctory and lacks context. Especially if the limitations and ethics sections are largely junk or missing                                                                                                                                                                                | Properly recapitulates the results and provides context for them. Has a sense of the limitatins and ethical issues.                                                                                                                                           | Clearly recapitulates the results and provides context, including the literature/background Has a sense of what to do next, and has good explorations of the limitations and ethics.                                                                                                                                                                              |
# | Documentation and written communication                                            | Code documentation is non-existent or perfunctory. Writing has usage errors, poor fluency, and poor rhetoric. If doc/writing are both like this you get unsatisfacory. If one is unsatisfactory and the other is developing you still get unsatisfactory overall.                                   | Code documentation is only partially there. Writing has some usage errors, some poor fluency, or some poor rhetoric. If doc/writing are both like this you get developing. If one is developing and the other is satisfactory you still get developing.                                                                             | Code is documented throughout. Writing has good fluency, good rhetoric, and at most a few minor errors.                                                                                                                                                       | Code documentation is highly informative with docstrings. Writing is high quality. If both doc/writing are like this you get excellent. If one is satisfactory and the other excellent you still get satisfactory.                                                                                                                                                |
# | Video (developing -1.5 points, unsatisfactory -3 points)                           | Video well outside the 3-5min time range. Does not communicate major results at a non-technical level. Has major technical issues such as no sound or not available at link. Unsatisfactory if 2/3 of these are true                                                                                | Video just outside the 3-5min time range. Does not communicate well on some points (either wrong tech level or just confusing). Has technical issues such as poor speech quality on video. Developing if 2/3 of these are true                                                                                                      | Video has good quality and is in within 3-5 min range. Communicates the major results at an accessible level for non-technical people.                                                                                                                        | Video has high production quality and is in within 3-5 min range. Communicates the major results clearly and gives a sense of the methods at an accessible level for non-technical people. Has a wow factor (e.g. funny or original approach)                                                                                                                     |
# | Quality modifier (can result in extra credit beyond 18 points for this assignment) | Almost everything was just barely proficient. Lots of minimal effort work. Do not double punish; if they already lost points on the rubric do not invoke this: -0.5 points                                                                                                                        |                                                                                                                                                                                                                                                                                                                                     |                                                                                                                                                                      |                                                                                                                                                                                                                                                                                                                       More than 5 excellents on this rubric: +0.5 points                                                                                   |

# %% [markdown]
# # COGS 108 - Final Project (change this to your project's title)
#
# ## Permissions
#
# Place an `X` in the appropriate bracket below to specify if you would like your group's project to be made available to the public, including the names of the authors.
#
# * [  ] YES - make available
# * [  ] NO - keep private
#
# ## Link to video
# https://link.to.your.publicly.viewable.video
#
# ## Abstract
#
# Please write one to four paragraphs that describe a very brief overview of why you did this, how you did, and the major findings and conclusions.

# %% [markdown]
# ## Authors
#
# > Analysis, Background research, Conceptualization, Data curation, Experimental investigation, Methodology, Project administration, Software, Visualization, Writing – original draft, Writing – review & editing
#
# Team list and credits:
# - Tom Rufino: Project administration, writing – original draft, experimental investigation
# - Summer Lenhart:  Background research, writing – original draft, visualization, slides design
# - Dylan Le: Data curation, software, writing – original draft, experimental investigation, visualization
# - Dylan Han: Background research, writing – original draft, review & editing

# %% [markdown]
# ## Research Question

# %% [markdown]
# __What attributes in US restaurants are associated with higher reviews on Yelp?__

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# The United States has one of the largest and most diverse restaurant industries in the world, with hundreds of thousands of establishments offering a wide range of cuisines, service styles, and dining experiences. With so many options available to consumers, online review platforms such as Yelp play a significant role in shaping customer decisions. Yelp allows users to rate restaurants and provide feedback based on their dining experience, creating large datasets that can be analyzed to better understand what factors contribute to a restaurant’s success. Attributes such as service quality, price range, ambience, and available amenities may influence how customers perceive restaurants and how they rate them online.
#
# In this project, we analyze Yelp data from restaurants across the United States to identify key features that contribute to higher ratings and customer satisfaction. By examining business attributes such as delivery options, reservations, outdoor seating, WiFi access, ambience, and accessibility features, we aim to determine which operational and environmental characteristics are most strongly associated with higher Yelp ratings. Understanding these relationships can help restaurant owners and managers better tailor their services and amenities to meet customer expectations.
#
# To begin our search for background data we explored a past project with a broader scope of restaurants in the US. It identified differences in rating distributions based on cuisine type, with statistical tests rejecting the possibility of these differences occurring by chance.<a name="cite_ref-2"></a>[<sup>2</sup>](#cite_note-2) Prior research has explored how different restaurant attributes influence customer satisfaction and online ratings. Studies using Yelp data have shown that ratings are not randomly distributed and that certain restaurant characteristics tend to be associated with stronger performance.
#
# Restaurant attributes such as service quality, price, and dining atmosphere are widely recognized as important contributors to customer satisfaction. Chun (2020) examined how restaurant attributes influence satisfaction, revisit intention, and customer recommendations, finding that food quality and service quality demonstrate strong positive correlations with customer satisfaction. While food quality itself is difficult to measure directly in large datasets, proxy indicators such as amenities, service options, and environment-related attributes may capture aspects of the overall dining experience that influence customer ratings.<a name="cite_ref-4"></a>[<sup>4</sup>](#cite_note-4)
#
# There has been prior research on what attributes on Yelp can contribute to a restaurant’s success. Studies using data from Yelp have found that data is not random and there are common denominators for success. One example found that across the US, restaurants have significant differences in cuisines which show that certain cuisines perform dramatically better than others because of customer’s preferences. Additionally, factors such as delivery options, reservations, and group accommodations were associated with higher star ratings on Yelp. These observations could potentially be found in the US market as well.
#
# Food quality was identified as the strongest predictor of satisfaction, even when controlling for other factors such as price and atmosphere. In the context of this project, food quality can be approximated using information extracted from Yelp review text, including sentiment, tone, and the presence of positive or negative words and phrases. Service quality, defined in the study as staff friendliness and speed of service, also demonstrated a strong positive relationship with customer satisfaction. On Yelp, service quality may be indirectly measured through business attributes such as Good for Groups, Reservations, and Delivery.<a name="cite_ref-5"></a>[<sup>5</sup>](#cite_note-5)
#
# Additionally, other studies analyzing Yelp data have identified operational features such as delivery availability, reservation options, and group accommodations as factors that can influence restaurant performance. These attributes reflect convenience and service accessibility, which are important elements of the modern dining experience. Environmental attributes, including ambience and outdoor seating, may also shape customer perceptions of the restaurant atmosphere and contribute to higher ratings.
#
# By analyzing these attributes across a large sample of restaurants in the United States, this project aims to identify patterns between restaurant characteristics and Yelp ratings. The results may provide insights into which amenities and operational features are most strongly associated with positive customer evaluations in the U.S. restaurant market.
#
# 1. <a name="cite_note-1"></a> [^](#city-ref-1) USA Restaurants – Total Count (2026). https://www.ckitchen.com/blog/2026/2/how-many-restaurants-are-in-the-u-s-2026.html?srsltid=AfmBOoppcrin5RKj-056PLcThyURIrjwZiTDBj1_Q718t03EhkbqxxQL.
# 2. <a name="cite_note-2"></a> [^](#cite-ref-2) Hecht, B., Hong, L., Suh, B., & Chi, E. H. (2020). Ratings matter: The impact of Yelp ratings on restaurant success. DATAUSA. https://brenthecht.com/publications/cscw2020_restaurantratings.pdf.
# 3. <a name="cite_note-3"></a> [^](#cite_ref-3) Wen Ma et al. (2020). COGS 108 - Final Project. https://github.com/COGS108/FinalProjects-Wi20/blob/master/FinalProject_group071.ipynb.
# 4. <a name="cite_note-4"></a> [^](#cite_ref-4) Chun, Se-Hak, and Ariunzaya Nyam-Ochir (Sept 2020). The Effects of Fast Food Restaurant Attributes on Customer Satisfaction, Revisit Intention, and Recommendation Using DINESERV Scale. *Sustainability*, *12*(18), 7435–35. https://doi.org/10.3390/su12187435.
# 5. <a name="cite_note-5"></a> [^](#cite_ref-5) Emitis Alikhani, Hassan F. Gholipour, Hossein Abbasinejad, and Ramtin Rafat Nezhad (May 2025). Review content and customer satisfaction: a textual analysis of Yelp restaurant reviews, 7435–35. https://www.sciencedirect.com/org/science/article/pii/S0007070X25000710

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# We predict that restaurants across the United States that offer customer-focused amenities and service features will predict higher star ratings. Specifically, restaurants that provide favorable dining environments and accessibility features, including outdoor seating and wifi availability, are expected to correlate with higher star ratings and greater review counts.

# %% [markdown]
# ## Data

# %% [markdown]
# ### Data overview

# %%
# Run this code every time when you're actively developing modules in .py files.  It's not needed if you aren't making modules
#
## this code is necessary for making sure that any modules we load are updated here 
## when their source code .py files are modified

# %load_ext autoreload
# %autoreload 2

# %%
# Setup code -- Run only once after cloning!!! 
#
# this code downloads the data from its source to the `data/00-raw/` directory
# if the data hasn't updated you don't need to do this again!

# if you don't already have these packages (you should!) uncomment this line
# %pip install requests tqdm

import sys
sys.path.append('./modules') # this tells python where to look for modules to import

import get_data # this is where we get the function we need to download data

datafiles = [
    { 'url': 'https://datahub.ucsd.edu/user/trufino/files/private/Group009_WI26/raw_yelp_academic_dataset_business.json?_xsrf=', 
     'filename':'raw_yelp.csv'}]

get_data.get_raw(datafiles,destination_directory='data/00-raw/')
# Out:
# ...
# Overall Download Progress: 100%|██████████| 1/1 [00:00<00:00, 16.02it/s]
# Successfully downloaded: raw_yelp.csv

# %% [markdown]
# ### Dataset #1: Yelp Open Dataset
#
# Here we take the Yelp API data from the Yelp Open Dataset, filter it to only restaurants, then clean the data.

# %%
import json
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.stats.anova import anova_lm
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import scipy.stats as stats
from scipy.stats import ttest_ind, chisquare, normaltest

# %%
def load_data(path):
    rows = []
    bad = 0

    with open(path, "r", encoding="utf-8", errors="replace") as f:
        for line_num, line in enumerate(f, start=1):
            line = line.strip()
            if not line:
                continue
            try:
                obj = json.loads(line)
                if isinstance(obj, dict) and "business_id" in obj:
                    rows.append(obj)
            except json.JSONDecodeError:
                bad += 1
                if bad <= 3:
                    print(f"Bad JSON on line {line_num}: {line[:200]}")

    print("Loaded records:", len(rows), "| Bad lines skipped:", bad)
    return pd.DataFrame.from_records(rows)

def filter_restaurants(df):
    df = df.copy()
    df["categories"] = df["categories"].fillna("")
    return df[df["categories"].str.contains("Restaurants", case=False, na=False)].copy()

def flatten_column(df, column, prefix):
    if column not in df.columns:
        return df
    expanded = pd.json_normalize(df[column].fillna({}))
    expanded.columns = [f"{prefix}{col}" for col in expanded.columns]
    df = df.drop(columns=[column]).reset_index(drop=True)
    return pd.concat([df, expanded.reset_index(drop=True)], axis=1)

def clean_types(df):
    df = df.copy()

    for col in ["stars", "review_count", "latitude", "longitude"]:
        if col in df.columns:
            df[col] = pd.to_numeric(df[col], errors="coerce")

    if "is_open" in df.columns:
        df["is_open"] = pd.to_numeric(df["is_open"], errors="coerce").map({0: False, 1: True})

    return df

def basic_cleanup(df):
    df = df.copy()

    if "business_id" in df.columns:
        df = df.drop_duplicates(subset=["business_id"])

    for col in ["name", "address", "city", "state", "postal_code"]:
        if col in df.columns:
            df[col] = df[col].replace("", np.nan)

    return df

# %%
def flatten_dict_column(df, col, prefix):
    if col not in df.columns:
        return df

    series = df[col].apply(lambda x: {} if pd.isna(x) else x)
    expanded = pd.json_normalize(series)
    expanded.columns = [f"{prefix}{c}" for c in expanded.columns]
    df = df.drop(columns=[col]).reset_index(drop=True)
    df = pd.concat([df, expanded], axis=1)

    return df

# %%
BUSINESS_JSON = "data/00-raw/raw_yelp_academic_dataset_business.json"
OUT_CSV = "data/02-processed/restaurants_clean.csv"

df = load_data(BUSINESS_JSON)

restaurants = filter_restaurants(df)

restaurants = flatten_column(restaurants, "attributes", "attr_")
restaurants = flatten_column(restaurants, "hours", "hours_")

restaurants = clean_types(restaurants)

restaurants = basic_cleanup(restaurants)

restaurants.to_csv(OUT_CSV, index=False)
print("Saved to:", OUT_CSV)
# Out:
# Bad JSON on line 1: "Sunday":"10:0-21:0"}}
# Bad JSON on line 11935: {"business_id":"6a23cjyRkIvjnTy-ffHJ7Q","name":"Brat's Bar & Grill","address":"5975 W Western Way Cir, Ste 106","city":"Tucson","state":"AZ","postal_code":"85713","latitude":32.186282,"longitude":-111
# Loaded records: 11933 | Bad lines skipped: 2
# Saved to: data/02-processed/restaurants_clean.csv

# %%
# create yelp_df dataset from processed, filtered Yelp data
yelp_df = pd.read_csv('data/02-processed/restaurants_clean.csv').reset_index()
yelp_df.head()
yelp_df.shape
# Out:
# (4156, 58)

# %%
yelp_df['state'].unique()
# Out:
# array(['IN', 'TN', 'MO', 'PA', 'FL', 'IL', 'LA', 'AB', 'NJ', 'CA', 'AZ',
#        'DE', 'NV', 'ID', 'MT'], dtype=object)

# %% [markdown]
# It looks like the US states provided from Yelp's Open Dataset are Indiana, Tennessee, Missouri, Pennsylvania, Florida, Illinois, Louisiana, New Jersey, California, Arizona, Delaware, Nevada, Idaho, and Montana.
#
# We do have some Alberta, Canada observations...to keep this relevant to the USA, let's check the value counts and remove all Alberta data.

# %%
AB_df = yelp_df[yelp_df['state'] == 'AB']
AB_df.shape # 205 observations
# Out:
# (205, 58)

# %%
# remove AB observations
usa_df = yelp_df[yelp_df['state'] != 'AB']
yelp_df = usa_df
yelp_df['state'].unique()
# Out:
# array(['IN', 'TN', 'MO', 'PA', 'FL', 'IL', 'LA', 'NJ', 'CA', 'AZ', 'DE',
#        'NV', 'ID', 'MT'], dtype=object)

# %%
yelp_df.shape
# Out:
# (3951, 58)

# %% [markdown]
# So we have 3951 restaurant observations to work with so far. Let's trim the attributes to those of interest!

# %%
yelp_df.columns # that's a lot of columns...
# Out:
# Index(['index', 'business_id', 'name', 'address', 'city', 'state',
#        'postal_code', 'latitude', 'longitude', 'stars', 'review_count',
#        'is_open', 'categories', 'attr_Ambience', 'attr_BusinessParking',
#        'attr_GoodForMeal', 'attr_RestaurantsTakeOut', 'attr_HasTV',
#        'attr_RestaurantsDelivery', 'attr_OutdoorSeating', 'attr_BikeParking',
#        'attr_RestaurantsGoodForGroups', 'attr_WiFi',
#        'attr_RestaurantsTableService', 'attr_RestaurantsReservations',
#        'attr_GoodForKids', 'attr_RestaurantsPriceRange2',
#        'attr_RestaurantsAttire', 'attr_DogsAllowed',
#        'attr_BusinessAcceptsCreditCards', 'attr_NoiseLevel', 'attr_Alcohol',
#        'attr_Caters', 'attr_WheelchairAccessible',
#        'attr_BusinessAcceptsBitcoin', 'attr_BYOBCorkage', 'attr_Corkage',
#        'attr_BestNights', 'attr_CoatCheck', 'attr_Music', 'attr_HappyHour',
#        'attr_Smoking', 'attr_BYOB', 'attr_ByAppointmentOnly', 'attr_DriveThru',
# ...

# %% [markdown]
# We will want to look at review counts and observe the relationship between review counts and stars; however, this data is likely to contain many outliers (for example, restaurants with 1000s of reviews if most might be less than 100). In order to make this data easier to work with (and less skewed), we will create a `log_review_count` column with the log-transformed `review_count` data.

# %%
# convert non-numeric values to NaN values, then drop the NaN values
df_rs = yelp_df.copy()
df_rs['stars'] = pd.to_numeric(df_rs['stars'], errors='coerce')
df_rs['review_count'] = pd.to_numeric(df_rs['review_count'], errors='coerce')
df_rs = df_rs.dropna(subset=['stars', 'review_count'])

df_rs.shape # it looks like this df is the same size as our original yelp_df!
# Out:
# (3951, 58)

# %%
yelp_df = df_rs
# Log-transform review_count for plotting
yelp_df['log_review_count'] = np.log1p(yelp_df['review_count'])

# %% [markdown]
# Making the `attr_Alcohol` data binary here.

# %%
yelp_df['attr_Alcohol'].unique()
# Out:
# array([nan, "u'none'", "'full_bar'", "u'beer_and_wine'", "u'full_bar'",
#        "'none'", "'beer_and_wine'"], dtype=object)

# %%
df_alc = yelp_df.copy()
alc = df_alc['attr_Alcohol'].astype('string')
# clean the strings
alc_clean = (alc
             .str.strip()
             .str.strip('"')
             .str.strip("'")
             .str.lower())
# convert to binary, keeping NaNs
df_alc['alcohol_has'] = np.where(
    alc_clean.isna(),
    np.nan,
    alc_clean.isin(['full_bar', 'beer_and_wine']).astype(int)
)

yelp_df = df_alc

# %% [markdown]
# ## Results
#
# ### Exploratory Data Analysis

# %% [markdown]
# #### Stars and Review Counts
#
# We're going to start by looking at our data distributions for star ratings, then seeing what role review counts play in predicting a given restaurant's ratings.

# %%
plt.figure(figsize=(8, 4))

# bins from 1.0 to 5.0 in 0.5-star increments
bins = np.arange(1.0, 5.5, 0.5)
plt.hist(yelp_df['stars'], bins=bins, edgecolor='black')

plt.xlabel('Stars (rating)')
plt.ylabel('Number of restaurants')
plt.title('Distribution of Yelp Restaurant Ratings (Stars)')
plt.xticks(np.arange(1.0, 5.5, 0.5))

plt.tight_layout()
plt.show()

# %% [markdown]
# Looks like our star ratings is left-skewed, which makes sense intuitively as ideally most restaurants would not average a 3.0 star rating! Instead our mean looks closer to 4.0.
#
# Now let's take a look at the relationship between stars and review counts. Remember before when we log-transformed the `review_count` column? Let's take a look at why we might have done that.

# %%
plt.subplot(1, 2, 1)
plt.scatter(df_rs['review_count'], df_rs['stars'], alpha=0.25, s=12)
plt.xlabel('Review count')
plt.ylabel('Stars')
plt.title('Stars vs Review Count (raw)')
# Out:
# Text(0.5, 1.0, 'Stars vs Review Count (raw)')

# %% [markdown]
# As you can see, the outliers make it very difficult to properly visualize our data. Now let's use the log-transformed data:

# %%
plt.subplot(1, 2, 2)
plt.scatter(df_rs['log_review_count'], df_rs['stars'], alpha=0.25, s=12)
plt.xlabel('log1p(Review count)')
plt.ylabel('Stars')
plt.title('Stars vs Review Count (log transform)')
# Out:
# Text(0.5, 1.0, 'Stars vs Review Count (log transform)')

# %% [markdown]
# We'd now like to answer the question, "Are higher star ratings associated with higher review counts?" To do that, we will take this data and run an OLS regression test, with `log_review_count` as our predictor variable and `stars` as our response variable.

# %%
OLS_stars_reviews = smf.ols('stars ~ log_review_count', data=yelp_df).fit(cov_type='HC3')
print(OLS_stars_reviews.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  stars   R-squared:                       0.052
# Model:                            OLS   Adj. R-squared:                  0.052
# Method:                 Least Squares   F-statistic:                     259.0
# Date:                Wed, 18 Mar 2026   Prob (F-statistic):           1.70e-56
# Time:                        22:33:13   Log-Likelihood:                -4763.2
# No. Observations:                3951   AIC:                             9530.
# Df Residuals:                    3949   BIC:                             9543.
# Df Model:                           1
# Covariance Type:                  HC3
# ...
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept            2.9274      0.043     68.059      0.000       2.843       3.012
# ...

# %% [markdown]
# Looking at our OLS results, some things we can note:
#
# - Our p-value is extremely small (much less than α<0.05), so there is a statistically significant chance that our results have an effect.
# - Our effect size for log_review_count is 0.16, suggesting a small positive effect.
# - Our R-squared value, at 0.052, suggests a small effect such that many other attributes are likely contributing to star number.
#
# Overall, we've learned from this data that there is a statistically significant relationship between review counts and star ratings on Yelp's Open Dataset. The direct relationship is very small, however, so it is worth exploring other attributes.

# %% [markdown]
# ## Restaurant Attributes and Star Ratings
#
# Now we'll take a look at the attributes of interest that we selected earlier and take a look at their relationship with star ratings.
#
# ### 1. Serving Alcohol and the Star Ratings
# We'll start with alcohol; we coded our data earlier, now we can create plots to compare non-alcohol vs. alcohol providing restaurants.

# %%
df_alc_known = yelp_df.dropna(subset=['alcohol_has'])
counts = df_alc_known['alcohol_has'].value_counts().sort_index()

plt.figure(figsize=(6, 4))
sns.boxplot(data=df_alc_known, x='alcohol_has', y='stars')
plt.xticks([0, 1], [f"No/NaN (n={counts.get(0,0)})", f"Has alcohol (n={counts.get(1,0)})"])
plt.xlabel("Alcohol")
plt.ylabel("Stars")
plt.title("Stars by Alcohol Availability (based on known entries)")
plt.tight_layout()
plt.show()

# %%
model_alc = smf.ols('stars ~ alcohol_has', data=df_alc_known).fit(cov_type='HC3')
print(model_alc.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  stars   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                   0.01027
# Date:                Wed, 18 Mar 2026   Prob (F-statistic):              0.919
# Time:                        22:33:13   Log-Likelihood:                -3416.0
# No. Observations:                3008   AIC:                             6836.
# Df Residuals:                    3006   BIC:                             6848.
# Df Model:                           1
# Covariance Type:                  HC3
# ...
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       3.5417      0.015    241.388      0.000       3.513       3.570
# ...

# %% [markdown]
# Here are some notable points from the results:
#
# - Our p-value is very large at 0.919, meaning the difference in star ratings from alcohol availability is very likely to have occurred by chance.
# - Our R-squared value is extremely small, suggesting little-to-no effect.
#
# We can clearly conclude from the data that alcohol is not a significant predictor for restaurant rating. There are likely other attributes which contribute more to a restaurant's rating than whether or not they serve alcohol!

# %% [markdown]
# ### 2. Outdoor Seating and the Star Ratings
# Outdoor seating is a common customer-facing amenity that may improve the dining experience.

# %%
df_outdoor = yelp_df.copy()

outdoor = df_outdoor['attr_OutdoorSeating'].astype('string')

outdoor_clean = (
    outdoor
    .str.lower()
    .str.strip()
)

df_outdoor['outdoor_seating'] = outdoor_clean.map({
    'true': 1,
    'false': 0
})

df_outdoor_known = df_outdoor.dropna(subset=['outdoor_seating'])

plt.figure(figsize=(6,4))
sns.boxplot(x='outdoor_seating', y='stars', data=df_outdoor_known)
plt.xticks([0,1], ['No Outdoor Seating','Outdoor Seating'])
plt.title('Stars By Outdoor Seating Availability (based on known entries)')
plt.ylabel('Stars')
plt.xlabel('')
plt.show()

# %%
model_outdoor = smf.ols('stars ~ outdoor_seating', data=df_outdoor_known).fit(cov_type='HC3')
print(model_outdoor.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  stars   R-squared:                       0.031
# Model:                            OLS   Adj. R-squared:                  0.031
# Method:                 Least Squares   F-statistic:                     102.8
# Date:                Wed, 18 Mar 2026   Prob (F-statistic):           8.53e-24
# Time:                        22:33:13   Log-Likelihood:                -3684.0
# No. Observations:                3170   AIC:                             7372.
# Df Residuals:                    3168   BIC:                             7384.
# Df Model:                           1
# Covariance Type:                  HC3
# ...
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           3.3779      0.020    165.574      0.000       3.338       3.418
# ...

# %% [markdown]
# With a statistically significant p-value, we can conclude a significant difference in star ratings between restaurants who do and do not offer outdoor seating. Our effect size is positive and moderately small, suggesting that offering outdoor seating is predictive of higher star ratings! Although, with a low R-squared we cannot conclude this single variable predicts the overall variance in star ratings.

# %% [markdown]
# ### 3. WiFi and the Star Ratings
# The digital world has nurtured food goers to appreciate WiFi services.

# %%
df_wifi = yelp_df.copy()

wifi_col = None
for c in ["attr_WiFi", "WiFi", "attributes.WiFi", "attributes_WiFi"]:
    if c in df_wifi.columns:
        wifi_col = c
        break

if wifi_col is None:
    raise KeyError("Couldn't find a WiFi column. Look for a column containing 'WiFi' in yelp_df.columns.")

wifi = df_wifi[wifi_col].astype("string")

wifi_clean = (
    wifi.str.lower()
        .str.strip()
        .str.replace(r"^u'", "", regex=True)     # u'free' -> free'
        .str.replace("'", "", regex=False)       # remove single quotes
        .str.replace('"', "", regex=False)       # remove double quotes if any
        .str.strip()
)

df_wifi["wifi_available"] = wifi_clean.map({
    "free": 1,
    "paid": 1,
    "no": 0,
    "none": 0
})

df_wifi_known = df_wifi.dropna(subset=["wifi_available"]).copy()

plt.figure(figsize=(6,4))
sns.boxplot(x="wifi_available", y="stars", data=df_wifi_known)
plt.xticks([0,1], ["No WiFi", "WiFi Available"])
plt.title("WiFi Availability vs Yelp Star Ratings")
plt.ylabel("Stars")
plt.xlabel("")
plt.show()

# %%
model_wifi = smf.ols("stars ~ wifi_available", data=df_wifi_known).fit(cov_type="HC3")
print(model_wifi.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  stars   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     7.709
# Date:                Wed, 18 Mar 2026   Prob (F-statistic):            0.00553
# Time:                        22:33:13   Log-Likelihood:                -3335.7
# No. Observations:                2878   AIC:                             6675.
# Df Residuals:                    2876   BIC:                             6687.
# Df Model:                           1
# Covariance Type:                  HC3
# ...
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept          3.5202      0.022    163.250      0.000       3.478       3.562
# ...

# %% [markdown]
# With a statistically significant p-value in our regression results, we can conclude a statistically significantly difference between offering and not offering wifi services at restaurants, with a very small positive effect for restaurants offering wifi. A very small R-squared suggests very little variance explained by wifi availability.
#
# So, wifi probably good, but also not the strongest predictor of a highly-rated restaurant. It's likely wifi is correlated with other attributes that are better predictors of star ratings!

# %% [markdown]
# ### 4. Menu Pricing and the Star Ratings
# Cost of food is a factor people consider when deciding the value of their meal; before and after going into an establishment.

# %%
df_price = yelp_df.copy()

price = df_price["attr_RestaurantsPriceRange2"].astype("string")
price_clean = price.str.replace("'", "", regex=False).str.strip()
df_price["price_range"] = pd.to_numeric(price_clean, errors="coerce")

df_price_known = df_price.dropna(subset=["price_range"]).copy()
df_price_known["price_group"] = df_price_known["price_range"].replace({4.0: 3.0})
df_price_known["price_group"] = df_price_known["price_group"].astype(float).astype(int)

plt.figure(figsize=(7,5))
sns.boxplot(data=df_price_known, x="price_group", y="stars")
plt.xticks([0,1,2], ["1", "2", "3.5"])
plt.title("Price Category vs Yelp Star Ratings")
plt.xlabel("Price Groups (3 and 4 combined due to so few 4's)")
plt.ylabel("Stars")
plt.show()

# %%
print(df_price_known.groupby("price_group")["stars"].agg(["mean","median","count"]))
# Out:
#                  mean  median  count
# price_group
# 1            3.279093     3.5   1521
# 2            3.581002     3.5   1716
# 3            3.708029     4.0    137

# %%
price_model = smf.ols('stars ~ C(price_group)', data=df_price_known).fit()
anova_table = sm.stats.anova_lm(price_model, typ=2)
anova_table
# Out:
#                      sum_sq      df          F        PR(>F)
# C(price_group)    82.997996     2.0  64.680382  2.724212e-28
# Residual        2162.836992  3371.0        NaN           NaN

# %%
tukey = pairwise_tukeyhsd(endog=df_price_known['stars'], groups=df_price_known['price_group'], alpha=0.05)
print(tukey)
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#      1      2   0.3019    0.0  0.2358 0.3681   True
#      1      3   0.4289    0.0  0.2614 0.5965   True
#      2      3    0.127 0.1743 -0.0397 0.2938  False
# ---------------------------------------------------

# %% [markdown]
# Using a one-way ANOVA, we identified that the 3 price groups' means differ from each other. With a very small p-value, we can reject our null hypothesis that the group means do not differ and conduct post-hoc tests.
#
# We conducted a Tukey post-hoc test to determine which price groups differ, and it identified group 1 differing from price groups 2 and 3, but without a significant difference between 2 and 3 themselves. It seems our lowest price group of 1 is actually a predictor of *lower* star ratings between all 3 groups!

# %% [markdown]
# ## Ethics

# %% [markdown]
# Items on this checklist are meant to provoke discussion among good-faith actors who take their ethical responsibilities seriously. Your teams will document these discussions and decisions for posterity using this section.  You don't have to solve these problems, you just have to acknowledge any potential harm no matter how unlikely.
#
# Here is a [list of real world examples](https://deon.drivendata.org/examples/) for each item in the checklist that can refer to.
#
# [![Deon badge](https://img.shields.io/badge/ethics%20checklist-deon-brightgreen.svg?style=popout-square)](http://deon.drivendata.org/)
#
# ### A. Data Collection
#  - [X] **A.1 Informed consent**: If there are human subjects, have they given informed consent, where subjects affirmatively opt-in and have a clear understanding of the data uses to which they consent?
#  - [X] **A.2 Collection bias**: Have we considered sources of bias that could be introduced during data collection and survey design and taken steps to mitigate those?
#
# > Yelp reviews tend to be highly positive or highly negative, could miss out on "eh" experiences. Review bombing and bot reviews are also items to consider as confounds in our data.
#
#  - [X] **A.3 Limit PII exposure**: Have we considered ways to minimize exposure of personally identifiable information (PII) for example through anonymization or not collecting information that isn't relevant for analysis?
#
# > Yelp API does not pull personally identifiable information.
#
#  - [X] **A.4 Downstream bias mitigation**: Have we considered ways to enable testing downstream results for biased outcomes (e.g., collecting data on protected group status like race or gender)?
#
# ### B. Data Storage
#  - [X] **B.1 Data security**: Do we have a plan to protect and secure data (e.g., encryption at rest and in transit, access controls on internal users and third parties, access logs, and up-to-date software)?
#  - [X] **B.2 Right to be forgotten**: Do we have a mechanism through which an individual can request their personal information be removed?
#  - [X] **B.3 Data retention plan**: Is there a schedule or plan to delete the data after it is no longer needed?
#
# ### C. Analysis
#  - [X] **C.1 Missing perspectives**: Have we sought to address blindspots in the analysis through engagement with relevant stakeholders (e.g., checking assumptions and discussing implications with affected communities and subject matter experts)?
#  - [X] **C.2 Dataset bias**: Have we examined the data for possible sources of bias and taken steps to mitigate or address these biases (e.g., stereotype perpetuation, confirmation bias, imbalanced classes, or omitted confounding variables)?
#  - [X] **C.3 Honest representation**: Are our visualizations, summary statistics, and reports designed to honestly represent the underlying data?
#  - [X] **C.4 Privacy in analysis**: Have we ensured that data with PII are not used or displayed unless necessary for the analysis?
#  - [X] **C.5 Auditability**: Is the process of generating the analysis well documented and reproducible if we discover issues in the future?
#
# ### D. Modeling
#  - [X] **D.1 Proxy discrimination**: Have we ensured that the model does not rely on variables or proxies for variables that are unfairly discriminatory?
#  - [X] **D.2 Fairness across groups**: Have we tested model results for fairness with respect to different affected groups (e.g., tested for disparate error rates)?
#  - [X] **D.3 Metric selection**: Have we considered the effects of optimizing for our defined metrics and considered additional metrics?
#
# > Yelp ratings, different attributes create a wide variety of criteria to choose from.
#
#  - [X] **D.4 Explainability**: Can we explain in understandable terms a decision the model made in cases where a justification is needed?
#  - [X] **D.5 Communicate limitations**: Have we communicated the shortcomings, limitations, and biases of the model to relevant stakeholders in ways that can be generally understood?
#
# ### E. Deployment
#  - [X] **E.1 Monitoring and evaluation**: Do we have a clear plan to monitor the model and its impacts after it is deployed (e.g., performance monitoring, regular audit of sample predictions, human review of high-stakes decisions, reviewing downstream impacts of errors or low-confidence decisions, testing for concept drift)?
#  - [X] **E.2 Redress**: Have we discussed with our organization a plan for response if users are harmed by the results (e.g., how does the data science team evaluate these cases and update analysis and models to prevent future harm)?
#  - [X] **E.3 Roll back**: Is there a way to turn off or roll back the model in production if necessary?
#  - [X] **E.4 Unintended use**: Have we taken steps to identify and prevent unintended uses and abuse of the model and do we have a plan to monitor these once the model is deployed?

# %% [markdown]
# ## Discusison and Conclusion
#
# We began with quite the ambitious question: What attributes predict a restaurant's performance on Yelp? Yelp, a platform for users to post their experiences at a variety of different businesses online, is a vital tool for many while determining where to bring their business. Restaurants provide a particular point of relevance to our group, with San Diego serving as a prominent hub for restaurants of different cuisines, vibes, and features. Some restaurants may be a common study spot with reliable wifi services and ample seating; others may be well-known for superior ambience providing guests with a breathtaking atmosphere; while others may just be really tasty! In this project, we aimed to identify certain attributes' effect in predicting a restaurants success on Yelp, using Yelp's Open Dataset.
#
# Our variables of interest in our data analysis were **review counts**, **alcohol availability**, **outdoor seating**, **wifi availability**, and **menu pricing**. As for predicting higher star ratings, we found positive relationships in higher review counts, outdoor seating availability, and wifi availability. Each of these variables, although associated with a positive increase in star ratings, did not explain overall variance for the model.
#
# As for alcohol availability, we found no relationship between star ratings and whether or not a restaurant serves alcohol. We expected this, since alcohol availability is not an attribute seen often mentioned in Yelp reviews compared to service/ambience. This attribute was still worth exploring in our dataset though, to determine what extent baseline features like this affect a restaurant's ratings.
#
# Lastly, we explored the impact of pricing categories on Yelp ratings, splitting Yelp's four price categories (\\$, \\$\\$, \\$\\$\\$, \\$\\$\\$\\$) to 3 categories by combining the latter 2 due to data availability. A one-way ANOVA followed by post-hoc tests identified a price category of 1 ($) differing from categories 2 (\\$\\$) and 3/4 (\\$\\$\\$/\\$\\$\\$\\$). We can identify our higher price categories, then, as associated with higher star ratings. One possible explanation could be that higher price ratings for a given restaurant may also be associated with other predictors of success, such as quality service and food.
#
# Several limitations must be acknowledged if we are to generalize these results. The first is that our data came solely from the Yelp Open Dataset, a publicly available list of over 150,000 businesses from the USA and Canada. The primary issue we found with this dataset is that business data is only selected from specific regions; for example, the only data in California were from regions near Santa Barbara and Truckee, which is not representative of a state with many diverse businesses and restaurants. If we were to have an ideal dataset to work with for this project, it would be a collection of nearly every restaurant from each state in the US. This would allow us to look at trends from state to state and even identify differences between regions in the same state.
#
# Overall, we have identified multiple important predictors for restaurants to consider as beneficial for their success. Positive Yelp reviews are vital for restaurants to understand how to cater to their local demographics, and the experience for
#
#
#
# Wrap it all up here.  Somewhere between 3 and 10 paragraphs roughly.
# 1. Summarize the important results you made
# 2. This is a good time to refer back to your Background section and review how this work extended the previous stuff.
# 3. Try to bring all the different results together into a bigger picture... what have we learned?
# 4. Often what we learned is confusing.  Discuss if there are contradictory results how that might have happened
# 5. Discuss the limitations of your work. e.g, is the dataset a biased sample? would more data make you more confident? would longitudinal instead of cross-sectional data helpful? is there evidence that the phenomena you're investigating may change over time? etc
# 8. If you would like, you can also say what the next steps in this investigation might be if the work was to continue outside this class
